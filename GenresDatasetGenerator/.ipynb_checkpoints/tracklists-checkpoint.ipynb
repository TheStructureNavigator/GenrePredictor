# %%
import pandas as pd

# %%
e1 = pd.read_csv('Electronic.csv')
e2 = pd.read_csv('Electronic1.csv')
e3 = pd.read_csv('Electronic2.csv')

# %%
e = pd.concat([e1, e2, e3])

# %%
e = e.drop_duplicates()

# %%
e.to_csv('ElectronicGenre.csv')

# %%
ElectronicGenre = pd.read_csv('ElectronicGenre.csv').drop(columns = 'Unnamed: 0')

# %%
ElectronicGenre
# Out:
#                                  Track URI  danceability  energy  key  \
# 0     spotify:track:7aJgh6LCvhXJfD7PHjhG70         0.774   0.693    5
# 1     spotify:track:2iPbxmQ4Qil8KsGFeykGyv         0.671   0.813    5
# 2     spotify:track:3BKD1PwArikchz2Zrlp1qi         0.602   0.910    7
# 3     spotify:track:2F2p7b5Xq20mRyEeWYaeUF         0.690   0.890    0
# 4     spotify:track:6pb5DtlAeG95dNQLHiArRU         0.662   0.821    2
# ...                                    ...           ...     ...  ...
# 1031  spotify:track:28O4PwkH8bzARStxeL4pxL         0.815   0.633   11
# 1032  spotify:track:5xYC48nOppVemY6U5GRGTb         0.546   0.916    8
# 1033  spotify:track:2fSYvZd64iOMjif8HbxbG6         0.741   0.838   11
# 1034  spotify:track:4OZEu0Vwq0RB2LAq14v99n         0.611   0.700    9
# 1035  spotify:track:1a5Yu5L18qNxVhXx38njON         0.788   0.430   11
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...
